# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tensorboardX import SummaryWriter

# %%
# 定义全局变量
# 更改nEpochs = 10
modelPath = './model.pkl'
batchSize = 5
nEpochs = 10
numPrint = 1000
# 定义Summary_Writer
writer = SummaryWriter('./Result')   # 数据存放在这个文件夹
# cuda
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 加载数据集 (训练集和测试集)
trainset = torchvision.datasets.CIFAR10(root='./Cifar-10', train=True, download=True, transform=transforms.ToTensor())
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchSize, shuffle=True)
testset = torchvision.datasets.CIFAR10(root='./Cifar-10', train=False, download=True, transform=transforms.ToTensor())
testloader = torch.utils.data.DataLoader(testset, batch_size=batchSize, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./Cifar-10\cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./Cifar-10\cifar-10-python.tar.gz to ./Cifar-10
# Files already downloaded and verified

# %%
# 定义神经网络  
class Net(nn.Module):  # 训练 ALexNet
    '''
    三层卷积，三层全连接  (应该是5层卷积，由于图片是 32 * 32，且为了效率，这里设成了 3 层)
    ''' 
    def __init__(self):
        super(Net, self).__init__()
        # 五个卷积层
        self.conv1 = nn.Sequential(  # 输入 32 * 32 * 3
            nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, stride=1, padding=1),   # (32-3+2)/1+1 = 32
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (32-2)/2+1 = 16
        )
        self.conv2 = nn.Sequential(  # 输入 16 * 16 * 6
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=3, stride=1, padding=1),  # (16-3+2)/1+1 = 16
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (16-2)/2+1 = 8
        )
        self.conv3 = nn.Sequential(  # 输入 8 * 8 * 16
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1), # (8-3+2)/1+1 = 8
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (8-2)/2+1 = 4
        )
        self.conv4 = nn.Sequential(  # 输入 4 * 4 * 64
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1), # (4-3+2)/1+1 = 4
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (4-2)/2+1 = 2
        )
        self.conv5 = nn.Sequential(  # 输入 2 * 2 * 128
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),# (2-3+2)/1+1 = 2
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (2-2)/2+1 = 1
        )                            # 最后一层卷积层，输出 1 * 1 * 128
        # 全连接层
        self.dense = nn.Sequential(
            nn.Linear(128, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 10)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = x.view(-1, 128)
        x = self.dense(x)
        return x

net = Net().to(device)

# 使用测试数据测试网络
def Accuracy():
    correct = 0
    total = 0
    with torch.no_grad():  # 训练集中不需要反向传播
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device) # 将输入和目标在每一步都送入GPU
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)  # 返回每一行中最大值的那个元素，且返回其索引
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    return 100.0 * correct / total

# %%
# 训练函数
def train():
    # 定义损失函数和优化器
    criterion = nn.CrossEntropyLoss()  # 交叉熵损失
    optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)  # 随机梯度下降
    iter = 0
    num = 1
    # 训练网络
    for epoch in range(nEpochs):  # loop over the dataset multiple times
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            iter = iter + 1
            # 取数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)  # 将输入和目标在每一步都送入GPU
            # 将梯度置零
            optimizer.zero_grad()
            # 训练
            outputs = net(inputs)
            loss = criterion(outputs, labels).to(device)
            loss.backward()   # 反向传播
            writer.add_scalar('loss', loss.item(), iter)
            optimizer.step()  # 优化
            # 统计数据
            running_loss += loss.item()
            if i % numPrint == 999:    # 每 batchsize * numPrint 张图片，打印一次
                print('epoch: %d\t batch: %d\t loss: %.6f' % (epoch + 1, i + 1, running_loss / (batchSize*numPrint)))
                running_loss = 0.0
                writer.add_scalar('accuracy', Accuracy(), num + 1)
                num = num + 1
    # 保存模型
    torch.save(net, './model.pkl')

# %%
if __name__ == '__main__':
    # 如果模型存在，加载模型
    if os.path.exists(modelPath):
        print('model exits')
        net = torch.load(modelPath)
        print('model loaded')
    else:
        print('model not exits')
    print('Training Started')
    train()
    writer.close()
    print('Training Finished')
# Out:
# model not exits
# Training Started
# D:\Software-Code\Anacoda\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# epoch: 1	 batch: 1000	 loss: 0.460755
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 2000	 loss: 0.460596
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 3000	 loss: 0.460666
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 4000	 loss: 0.460530
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 5000	 loss: 0.460661
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 6000	 loss: 0.460459
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 7000	 loss: 0.460630
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 8000	 loss: 0.460422
# Accuracy of the network on the 10000 test images: 13 %
# epoch: 1	 batch: 9000	 loss: 0.460203
# Accuracy of the network on the 10000 test images: 12 %
# epoch: 1	 batch: 10000	 loss: 0.459169
# Accuracy of the network on the 10000 test images: 16 %
# epoch: 2	 batch: 1000	 loss: 0.448965
# Accuracy of the network on the 10000 test images: 18 %
# epoch: 2	 batch: 2000	 loss: 0.431323
# Accuracy of the network on the 10000 test images: 20 %
# epoch: 2	 batch: 3000	 loss: 0.418970
# Accuracy of the network on the 10000 test images: 20 %
# epoch: 2	 batch: 4000	 loss: 0.410155
# Accuracy of the network on the 10000 test images: 25 %
# epoch: 2	 batch: 5000	 loss: 0.403814
# Accuracy of the network on the 10000 test images: 21 %
# epoch: 2	 batch: 6000	 loss: 0.399005
# Accuracy of the network on the 10000 test images: 26 %
# epoch: 2	 batch: 7000	 loss: 0.394418
# Accuracy of the network on the 10000 test images: 27 %
# epoch: 2	 batch: 8000	 loss: 0.385937
# Accuracy of the network on the 10000 test images: 29 %
# epoch: 2	 batch: 9000	 loss: 0.376270
# Accuracy of the network on the 10000 test images: 28 %
# epoch: 2	 batch: 10000	 loss: 0.368946
# Accuracy of the network on the 10000 test images: 31 %
# epoch: 3	 batch: 1000	 loss: 0.368279
# Accuracy of the network on the 10000 test images: 32 %
# epoch: 3	 batch: 2000	 loss: 0.358108
# Accuracy of the network on the 10000 test images: 35 %
# epoch: 3	 batch: 3000	 loss: 0.348058
# Accuracy of the network on the 10000 test images: 35 %
# epoch: 3	 batch: 4000	 loss: 0.342917
# Accuracy of the network on the 10000 test images: 39 %
# epoch: 3	 batch: 5000	 loss: 0.329540
# Accuracy of the network on the 10000 test images: 39 %
# epoch: 3	 batch: 6000	 loss: 0.327962
# Accuracy of the network on the 10000 test images: 42 %
# epoch: 3	 batch: 7000	 loss: 0.314634
# Accuracy of the network on the 10000 test images: 41 %
# epoch: 3	 batch: 8000	 loss: 0.319637
# Accuracy of the network on the 10000 test images: 42 %
# epoch: 3	 batch: 9000	 loss: 0.314280
# Accuracy of the network on the 10000 test images: 41 %
# epoch: 3	 batch: 10000	 loss: 0.308028
# Accuracy of the network on the 10000 test images: 42 %
# epoch: 4	 batch: 1000	 loss: 0.303472
# Accuracy of the network on the 10000 test images: 43 %
# epoch: 4	 batch: 2000	 loss: 0.297736
# Accuracy of the network on the 10000 test images: 46 %
# epoch: 4	 batch: 3000	 loss: 0.292509
# Accuracy of the network on the 10000 test images: 46 %
# epoch: 4	 batch: 4000	 loss: 0.291994
# Accuracy of the network on the 10000 test images: 47 %
# epoch: 4	 batch: 5000	 loss: 0.285478
# Accuracy of the network on the 10000 test images: 41 %
# epoch: 4	 batch: 6000	 loss: 0.284511
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 4	 batch: 7000	 loss: 0.280713
# Accuracy of the network on the 10000 test images: 47 %
# epoch: 4	 batch: 8000	 loss: 0.277491
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 4	 batch: 9000	 loss: 0.277293
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 4	 batch: 10000	 loss: 0.270715
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 5	 batch: 1000	 loss: 0.261555
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 5	 batch: 2000	 loss: 0.264418
# Accuracy of the network on the 10000 test images: 47 %
# epoch: 5	 batch: 3000	 loss: 0.259503
# Accuracy of the network on the 10000 test images: 52 %
# epoch: 5	 batch: 4000	 loss: 0.259961
# Accuracy of the network on the 10000 test images: 53 %
# epoch: 5	 batch: 5000	 loss: 0.256698
# Accuracy of the network on the 10000 test images: 54 %
# epoch: 5	 batch: 6000	 loss: 0.254794
# Accuracy of the network on the 10000 test images: 53 %
# epoch: 5	 batch: 7000	 loss: 0.255926
# Accuracy of the network on the 10000 test images: 54 %
# epoch: 5	 batch: 8000	 loss: 0.252113
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 5	 batch: 9000	 loss: 0.246178
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 5	 batch: 10000	 loss: 0.246854
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 6	 batch: 1000	 loss: 0.233861
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 6	 batch: 2000	 loss: 0.236263
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 6	 batch: 3000	 loss: 0.233632
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 4000	 loss: 0.236608
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 6	 batch: 5000	 loss: 0.235722
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 6	 batch: 6000	 loss: 0.230320
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 6	 batch: 7000	 loss: 0.228322
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 6	 batch: 8000	 loss: 0.235886
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 6	 batch: 9000	 loss: 0.229962
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 10000	 loss: 0.230348
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 7	 batch: 1000	 loss: 0.215089
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 7	 batch: 2000	 loss: 0.216669
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 3000	 loss: 0.216195
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 7	 batch: 4000	 loss: 0.212665
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 7	 batch: 5000	 loss: 0.215770
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 7	 batch: 6000	 loss: 0.221576
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 7	 batch: 7000	 loss: 0.218332
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 7	 batch: 8000	 loss: 0.215320
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 7	 batch: 9000	 loss: 0.210481
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 7	 batch: 10000	 loss: 0.213487
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 8	 batch: 1000	 loss: 0.204973
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 8	 batch: 2000	 loss: 0.200444
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 8	 batch: 3000	 loss: 0.203766
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 8	 batch: 4000	 loss: 0.201119
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 8	 batch: 5000	 loss: 0.206079
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 8	 batch: 6000	 loss: 0.208621
# Accuracy of the network on the 10000 test images: 62 %
# epoch: 8	 batch: 7000	 loss: 0.200619
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 8	 batch: 8000	 loss: 0.196819
# Accuracy of the network on the 10000 test images: 62 %
# epoch: 8	 batch: 9000	 loss: 0.201909
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 8	 batch: 10000	 loss: 0.203841
# Accuracy of the network on the 10000 test images: 62 %
# epoch: 9	 batch: 1000	 loss: 0.188740
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 9	 batch: 2000	 loss: 0.188928
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 9	 batch: 3000	 loss: 0.190070
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 9	 batch: 4000	 loss: 0.191332
# Accuracy of the network on the 10000 test images: 64 %
# epoch: 9	 batch: 5000	 loss: 0.190540
# Accuracy of the network on the 10000 test images: 62 %
# epoch: 9	 batch: 6000	 loss: 0.194439
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 9	 batch: 7000	 loss: 0.195497
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 9	 batch: 8000	 loss: 0.193643
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 9	 batch: 9000	 loss: 0.189248
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 9	 batch: 10000	 loss: 0.191489
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 10	 batch: 1000	 loss: 0.173182
# Accuracy of the network on the 10000 test images: 64 %
# epoch: 10	 batch: 2000	 loss: 0.180091
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 10	 batch: 3000	 loss: 0.180194
# Accuracy of the network on the 10000 test images: 61 %
# epoch: 10	 batch: 4000	 loss: 0.186092
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 10	 batch: 5000	 loss: 0.178210
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 10	 batch: 6000	 loss: 0.181533
# Accuracy of the network on the 10000 test images: 64 %
# epoch: 10	 batch: 7000	 loss: 0.182241
# Accuracy of the network on the 10000 test images: 64 %
# epoch: 10	 batch: 8000	 loss: 0.180533
# Accuracy of the network on the 10000 test images: 63 %
# epoch: 10	 batch: 9000	 loss: 0.181141
# Accuracy of the network on the 10000 test images: 64 %
# epoch: 10	 batch: 10000	 loss: 0.187144
# Accuracy of the network on the 10000 test images: 65 %
# Training Finished
