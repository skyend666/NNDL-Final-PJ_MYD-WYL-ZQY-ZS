# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tensorboardX import SummaryWriter

# %%
# 定义全局变量
modelPath = './model.pkl'
batchSize = 5
nEpochs = 20
numPrint = 1000

# 定义Cutout变量
n_holes = 1
length = 4

# 定义Summary_Writer
writer = SummaryWriter('./Result')   # 数据存放在这个文件夹
# cuda
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# 定义Cutout图像处理
class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y0 = np.random.randint(h)
            x0 = np.random.randint(w)

            y1 = np.clip(y0 - self.length // 2, 0, h)
            y2 = np.clip(y0 + self.length // 2, 0, h)
            x1 = np.clip(x0 - self.length // 2, 0, w)
            x2 = np.clip(x0 + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %%
# 定义训练集、测试集变换
transform_train = transforms.Compose([transforms.ToTensor(),Cutout(n_holes, length)])
transform_test = transforms.Compose([transforms.ToTensor()])

# 加载数据集 (训练集和测试集)
trainset = torchvision.datasets.CIFAR10(root='./Cifar-10', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchSize, shuffle=True)
testset = torchvision.datasets.CIFAR10(root='./Cifar-10', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batchSize, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 定义Alex神经网络  
class Net(nn.Module):  # 训练 ALexNet
    '''
    三层卷积，三层全连接  (应该是5层卷积，由于图片是 32 * 32，且为了效率，这里设成了 3 层)
    ''' 
    def __init__(self):
        super(Net, self).__init__()
        # 五个卷积层
        self.conv1 = nn.Sequential(  # 输入 32 * 32 * 3
            nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, stride=1, padding=1),   # (32-3+2)/1+1 = 32
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (32-2)/2+1 = 16
        )
        self.conv2 = nn.Sequential(  # 输入 16 * 16 * 6
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=3, stride=1, padding=1),  # (16-3+2)/1+1 = 16
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (16-2)/2+1 = 8
        )
        self.conv3 = nn.Sequential(  # 输入 8 * 8 * 16
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1), # (8-3+2)/1+1 = 8
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (8-2)/2+1 = 4
        )
        self.conv4 = nn.Sequential(  # 输入 4 * 4 * 64
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1), # (4-3+2)/1+1 = 4
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (4-2)/2+1 = 2
        )
        self.conv5 = nn.Sequential(  # 输入 2 * 2 * 128
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),# (2-3+2)/1+1 = 2
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0)  # (2-2)/2+1 = 1
        )                            # 最后一层卷积层，输出 1 * 1 * 128
        # 全连接层
        self.dense = nn.Sequential(
            nn.Linear(128, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 10)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = x.view(-1, 128)
        x = self.dense(x)
        return x

net = Net().to(device)

# 使用测试数据测试网络
def Accuracy():
    correct = 0
    total = 0
    with torch.no_grad():  # 训练集中不需要反向传播
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device) # 将输入和目标在每一步都送入GPU
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)  # 返回每一行中最大值的那个元素，且返回其索引
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    return 100.0 * correct / total

# %%
# 定义训练函数
def train():
    # 定义损失函数和优化器
    criterion = nn.CrossEntropyLoss()  # 交叉熵损失
    optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)  # 随机梯度下降
    iter = 0
    num = 1
    # 训练网络
    for epoch in range(nEpochs):  # loop over the dataset multiple times
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            iter = iter + 1
            # 取数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)  # 将输入和目标在每一步都送入GPU
            # 将梯度置零
            optimizer.zero_grad()
            # 训练
            outputs = net(inputs)
            loss = criterion(outputs, labels).to(device)
            loss.backward()   # 反向传播
            writer.add_scalar('loss', loss.item(), iter)
            optimizer.step()  # 优化
            # 统计数据
            running_loss += loss.item()
            if i % numPrint == 999:    # 每 batchsize * numPrint 张图片，打印一次
                print('epoch: %d\t batch: %d\t loss: %.6f' % (epoch + 1, i + 1, running_loss / (batchSize*numPrint)))
                running_loss = 0.0
                writer.add_scalar('accuracy', Accuracy(), num + 1)
                num = num + 1
    # 保存模型
    torch.save(net, './model.pkl')

# %%
if __name__ == '__main__':
    # 如果模型存在，加载模型
    if os.path.exists(modelPath):
        print('model exits')
        net = torch.load(modelPath)
        print('model loaded')
    else:
        print('model not exits')
    print('Training Started')
    train()
    writer.close()
    print('Training Finished')
# Out:
# model not exits
# Training Started
# epoch: 1	 batch: 1000	 loss: 0.460854
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 2000	 loss: 0.460640
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 3000	 loss: 0.460639
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 4000	 loss: 0.460661
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 5000	 loss: 0.460586
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 6000	 loss: 0.460594
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 7000	 loss: 0.460420
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 8000	 loss: 0.460277
# Accuracy of the network on the 10000 test images: 10 %
# epoch: 1	 batch: 9000	 loss: 0.459251
# Accuracy of the network on the 10000 test images: 14 %
# epoch: 1	 batch: 10000	 loss: 0.445711
# Accuracy of the network on the 10000 test images: 19 %
# epoch: 2	 batch: 1000	 loss: 0.425092
# Accuracy of the network on the 10000 test images: 20 %
# epoch: 2	 batch: 2000	 loss: 0.418154
# Accuracy of the network on the 10000 test images: 23 %
# epoch: 2	 batch: 3000	 loss: 0.408819
# Accuracy of the network on the 10000 test images: 23 %
# epoch: 2	 batch: 4000	 loss: 0.400874
# Accuracy of the network on the 10000 test images: 25 %
# epoch: 2	 batch: 5000	 loss: 0.394917
# Accuracy of the network on the 10000 test images: 26 %
# epoch: 2	 batch: 6000	 loss: 0.390188
# Accuracy of the network on the 10000 test images: 26 %
# epoch: 2	 batch: 7000	 loss: 0.381628
# Accuracy of the network on the 10000 test images: 28 %
# epoch: 2	 batch: 8000	 loss: 0.368833
# Accuracy of the network on the 10000 test images: 32 %
# epoch: 2	 batch: 9000	 loss: 0.365334
# Accuracy of the network on the 10000 test images: 32 %
# epoch: 2	 batch: 10000	 loss: 0.356965
# Accuracy of the network on the 10000 test images: 36 %
# epoch: 3	 batch: 1000	 loss: 0.350878
# Accuracy of the network on the 10000 test images: 37 %
# epoch: 3	 batch: 2000	 loss: 0.338137
# Accuracy of the network on the 10000 test images: 40 %
# epoch: 3	 batch: 3000	 loss: 0.333511
# Accuracy of the network on the 10000 test images: 42 %
# epoch: 3	 batch: 4000	 loss: 0.332938
# Accuracy of the network on the 10000 test images: 43 %
# epoch: 3	 batch: 5000	 loss: 0.324594
# Accuracy of the network on the 10000 test images: 42 %
# epoch: 3	 batch: 6000	 loss: 0.323767
# Accuracy of the network on the 10000 test images: 43 %
# epoch: 3	 batch: 7000	 loss: 0.312627
# Accuracy of the network on the 10000 test images: 38 %
# epoch: 3	 batch: 8000	 loss: 0.310869
# Accuracy of the network on the 10000 test images: 43 %
# epoch: 3	 batch: 9000	 loss: 0.304061
# Accuracy of the network on the 10000 test images: 43 %
# epoch: 3	 batch: 10000	 loss: 0.307561
# Accuracy of the network on the 10000 test images: 45 %
# epoch: 4	 batch: 1000	 loss: 0.300662
# Accuracy of the network on the 10000 test images: 46 %
# epoch: 4	 batch: 2000	 loss: 0.297370
# Accuracy of the network on the 10000 test images: 47 %
# epoch: 4	 batch: 3000	 loss: 0.294735
# Accuracy of the network on the 10000 test images: 48 %
# epoch: 4	 batch: 4000	 loss: 0.289302
# Accuracy of the network on the 10000 test images: 49 %
# epoch: 4	 batch: 5000	 loss: 0.283219
# Accuracy of the network on the 10000 test images: 48 %
# epoch: 4	 batch: 6000	 loss: 0.284638
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 4	 batch: 7000	 loss: 0.282168
# Accuracy of the network on the 10000 test images: 50 %
# epoch: 4	 batch: 8000	 loss: 0.281211
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 4	 batch: 9000	 loss: 0.274499
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 4	 batch: 10000	 loss: 0.272028
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 5	 batch: 1000	 loss: 0.273126
# Accuracy of the network on the 10000 test images: 52 %
# epoch: 5	 batch: 2000	 loss: 0.262046
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 5	 batch: 3000	 loss: 0.264672
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 5	 batch: 4000	 loss: 0.257956
# Accuracy of the network on the 10000 test images: 53 %
# epoch: 5	 batch: 5000	 loss: 0.263213
# Accuracy of the network on the 10000 test images: 53 %
# epoch: 5	 batch: 6000	 loss: 0.262120
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 5	 batch: 7000	 loss: 0.256844
# Accuracy of the network on the 10000 test images: 53 %
# epoch: 5	 batch: 8000	 loss: 0.258984
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 5	 batch: 9000	 loss: 0.253954
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 5	 batch: 10000	 loss: 0.254665
# Accuracy of the network on the 10000 test images: 51 %
# epoch: 6	 batch: 1000	 loss: 0.246977
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 2000	 loss: 0.248866
# Accuracy of the network on the 10000 test images: 54 %
# epoch: 6	 batch: 3000	 loss: 0.241400
# Accuracy of the network on the 10000 test images: 54 %
# epoch: 6	 batch: 4000	 loss: 0.243341
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 6	 batch: 5000	 loss: 0.249286
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 6000	 loss: 0.241782
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 7000	 loss: 0.238496
# Accuracy of the network on the 10000 test images: 55 %
# epoch: 6	 batch: 8000	 loss: 0.249142
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 6	 batch: 9000	 loss: 0.238614
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 6	 batch: 10000	 loss: 0.239619
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 7	 batch: 1000	 loss: 0.233202
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 2000	 loss: 0.229607
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 3000	 loss: 0.231315
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 7	 batch: 4000	 loss: 0.230936
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 7	 batch: 5000	 loss: 0.228168
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 6000	 loss: 0.225722
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 7	 batch: 7000	 loss: 0.232596
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 8000	 loss: 0.227299
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 7	 batch: 9000	 loss: 0.229079
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 7	 batch: 10000	 loss: 0.232128
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 8	 batch: 1000	 loss: 0.218727
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 8	 batch: 2000	 loss: 0.217027
# Accuracy of the network on the 10000 test images: 58 %
# epoch: 8	 batch: 3000	 loss: 0.219389
# Accuracy of the network on the 10000 test images: 57 %
# epoch: 8	 batch: 4000	 loss: 0.216111
# Accuracy of the network on the 10000 test images: 60 %
# epoch: 8	 batch: 5000	 loss: 0.221237
# Accuracy of the network on the 10000 test images: 59 %
# epoch: 8	 batch: 6000	 loss: 0.222315
# Accuracy of the network on the 10000 test images: 56 %
# epoch: 8	 batch: 7000	 loss: 0.218491
# Accuracy of the network on the 10000 test images: 60 %
# epoch: